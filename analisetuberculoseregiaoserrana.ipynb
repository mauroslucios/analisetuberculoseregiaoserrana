# %% [markdown]
# <a href="https://colab.research.google.com/github/mauroslucios/analisetuberculoseregiaoserrana/blob/feature%2Fdevelopmauro/analisetuberculoseregiaoserrana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de Tuberculose na Região Serrana de Petrópolis

# %%
# importando arquivo excel
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/notebooks/tuberculose-regiao-serrana.xlsx')
df
# Out:
#                    Regiao_Serrana    2019    2020   2021   2022
# 0                      Bom Jardim   53.57    0.00      1      2
# 1            Cachoeiras de Macacu   29.41   37.50  78.95  82.61
# 2                       Cantagalo   95.24  100.00  91.30  47.83
# 3                           Carmo  100.00   50.00    100  77.78
# 4                        Cordeiro   41.67   53.13  64.86  66.67
# 5                     Duas Barras    0.00   62.50     SC      0
# 6     Engenheiro Paulo de Frontin   94.02   96.77  97.53    100
# 7                      Guapimirim   94.02   96.77  97.53    100
# 8                          Macuco  100.00    0.00      1      2
# 9                   Nova Friburgo   87.20   85.50  86.03  80.56
# 10                     Petrópolis   96.79  100.00  103.3    100
# 11           Santa Maria Madalena  109.09  200.00     SC      0
# 12  São José do Vale do Rio Preto    0.00    0.00      0      0
# 13          São Sebastião do Alto    0.00    0.00      0      0
# ...

# %% [markdown]
# ## Características gerais da base de dados

# %%
casos_petropolis.tail()
# Out:
#      2019   2020   2021 2022
# 10  96.79  100.0  103.3  100

# %%
casos_petropolis.shape
# Out:
# (1, 4)

# %%
casos_petropolis.columns
# Out:
# Index([2019, 2020, 2021, 2022], dtype='object')

# %%
casos_petropolis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 10 to 10
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2019    1 non-null      float64
#  1   2020    1 non-null      float64
#  2   2021    1 non-null      object
#  3   2022    1 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 148.0+ bytes

# %%
#contando os casos de Petrópolis de todos os anos
casos_petropolis = df.query('Regiao_Serrana == "Petrópolis"')
casos_petropolis
# Out:
#    Regiao_Serrana   2019   2020   2021 2022
# 10     Petrópolis  96.79  100.0  103.3  100

# %%
#removendo a coluna de cidades
casos_petropolis = casos_petropolis.drop(columns=['Regiao_Serrana'])
casos_petropolis.copy()
casos_petropolis.head()
# Out:
#      2019   2020   2021 2022
# 10  96.79  100.0  103.3  100

# %%
#fazendo o somatório dos casos dos anos
casos_petropolis['Total'] = casos_petropolis.sum(axis=1)
print(casos_petropolis)
# Out:
#      2019   2020   2021 2022   Total
# 10  96.79  100.0  103.3  100  400.09
